# %% [markdown]
# # Case Study on Airbnb Properties

# %% [markdown]
# Q1. **Import `Pandas` and `NumPy` libraries**

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# Q2. **Read the dataset with the index column as `id` and display the first 5 rows of the DataFrame.**

# %%
prop_df = pd.read_csv(r'C:\Users\anves\Desktop\python data analysis\python daily classes\airbnb.csv',index_col='id')

prop_df.head(5)
# Out:
#             neighborhood        room_type  accommodates  bedrooms  price  \
# id
# 3686  Historic Anacostia     Private room             1       1.0     55
# 3943            Edgewood     Private room             2       1.0     71
# 4529    Eastland Gardens     Private room             4       1.0     54
# 4967            Edgewood     Private room             1       1.0     99
# 5589    Kalorama Heights  Entire home/apt             3       1.0     99
#
#       security_deposit  cleaning_fee  rating  superhost       response_time  \
# id
# 3686                25            25    4.60          0  a few days or more
# 3943                50             0    4.81          0                 NaN
# 4529                25            50    4.66          0  within a few hours
# 4967                50             0    4.74          1      within an hour
# 5589                50             0    4.54          0  within a few hours
#
#      acceptance_rate  host_since last_review  num_reviews  latitude  \
# id
# 3686             67%  2008-11-26  2021-08-09           76  38.86339
# 3943             NaN  2008-12-12  2021-09-11          434  38.91195
# 4529             NaN  2008-12-30  2019-07-05          102  38.90585
# 4967             85%  2009-01-26  2016-09-22           31  38.91409
# 5589             11%  2009-01-13  2020-03-05           95  38.91887
#
#       longitude  minimum_nights  maximum_nights
# id
# 3686  -76.98889               2             365
# 3943  -77.00456               2            1125
# 4529  -76.94469              30             180
# 4967  -76.99368               2             365
# 5589  -77.04008               5              24

# %% [markdown]
# Q3. **Get the complete description of the metadata of the DataFrame.**

# %%
prop_df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7805 entries, 0 to 7804
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                7805 non-null   int64
#  1   neighborhood      7805 non-null   object
#  2   room_type         7805 non-null   object
#  3   accommodates      7805 non-null   int64
#  4   bedrooms          7021 non-null   float64
#  5   price             7805 non-null   int64
#  6   security_deposit  7805 non-null   int64
#  7   cleaning_fee      7805 non-null   int64
#  8   rating            5912 non-null   float64
#  9   superhost         7805 non-null   int64
#  10  response_time     5002 non-null   object
#  11  acceptance_rate   5407 non-null   object
#  12  host_since        7795 non-null   object
#  13  last_review       5912 non-null   object
#  14  num_reviews       7805 non-null   int64
#  15  latitude          7805 non-null   float64
#  16  longitude         7805 non-null   float64
#  17  minimum_nights    7805 non-null   int64
#  18  maximum_nights    7805 non-null   int64
# dtypes: float64(4), int64(9), object(6)
# memory usage: 3.6 MB

# %% [markdown]
# Q4. **Get the `count` and the `percentage` of missing values in all of the columns rounded to 2 decimals.**

# %%
missing_vals = prop_df.isna()

# %%
missing_vals.sum()
# Out:
# neighborhood           0
# room_type              0
# accommodates           0
# bedrooms             784
# price                  0
# security_deposit       0
# cleaning_fee           0
# rating              1893
# superhost              0
# response_time       2803
# acceptance_rate     2398
# host_since            10
# last_review         1893
# num_reviews            0
# latitude               0
# longitude              0
# minimum_nights         0
# maximum_nights         0
# dtype: int64

# %%
missing_vals.mean().round(2)
# Out:
# neighborhood        0.00
# room_type           0.00
# accommodates        0.00
# bedrooms            0.10
# price               0.00
# security_deposit    0.00
# cleaning_fee        0.00
# rating              0.24
# superhost           0.00
# response_time       0.36
# acceptance_rate     0.31
# host_since          0.00
# last_review         0.24
# num_reviews         0.00
# latitude            0.00
# longitude           0.00
# minimum_nights      0.00
# maximum_nights      0.00
# dtype: float64

# %% [markdown]
# Q5. **Get the sum of the `price`, `security_deposit` and `cleaning_fee` columns without using the `+` operator, name it as `total_cost` and insert the same after the `cleaning_fee` column.**

# %%
total_price = prop_df[['price','security_deposit','cleaning_fee']].sum(axis=1)

# %%
total_price
# Out:
# 0       105
# 1       121
# 2       129
# 3       149
# 4       149
#        ...
# 7800    349
# 7801    250
# 7802    140
# 7803    139
# 7804    234
# Length: 7805, dtype: int64

# %% [markdown]
# Q6. **Drop the columns `lattitude` and `longitude` without re-assigning to a variable.**

# %%
prop_df.drop(['latitude','longitude'],axis=1)
# Out:
#             id        neighborhood        room_type  accommodates  bedrooms  \
# 0         3686  Historic Anacostia     Private room             1       1.0
# 1         3943            Edgewood     Private room             2       1.0
# 2         4529    Eastland Gardens     Private room             4       1.0
# 3         4967            Edgewood     Private room             1       1.0
# 4         5589    Kalorama Heights  Entire home/apt             3       1.0
# ...        ...                 ...              ...           ...       ...
# 7800  52261187            Downtown  Entire home/apt             2       1.0
# 7801  52263116      Near Southeast  Entire home/apt             2       1.0
# 7802  52269279     Brightwood Park     Private room             2       1.0
# 7803  52271085            West End  Entire home/apt             2       1.0
# 7804  52281658            Edgewood  Entire home/apt             7       2.0
#
#       price  security_deposit  cleaning_fee  rating  superhost  \
# 0        55                25            25    4.60          0
# 1        71                50             0    4.81          0
# 2        54                25            50    4.66          0
# 3        99                50             0    4.74          1
# 4        99                50             0    4.54          0
# ...     ...               ...           ...     ...        ...
# 7800    299                 0            50     NaN          0
# 7801    200                50             0     NaN          0
# 7802     40                50            50     NaN          0
# 7803    139                 0             0     NaN          0
# 7804    134                 0           100     NaN          0
#
#            response_time acceptance_rate  host_since last_review  num_reviews  \
# 0     a few days or more             67%  2008-11-26  2021-08-09           76
# 1                    NaN             NaN  2008-12-12  2021-09-11          434
# 2     within a few hours             NaN  2008-12-30  2019-07-05          102
# 3         within an hour             85%  2009-01-26  2016-09-22           31
# 4     within a few hours             11%  2009-01-13  2020-03-05           95
# ...                  ...             ...         ...         ...          ...
# 7800                 NaN            100%  2021-02-13         NaN            0
# 7801                 NaN             NaN  2016-12-05         NaN            0
# 7802      within an hour             94%  2015-06-15         NaN            0
# 7803                 NaN            100%  2020-12-24         NaN            0
# 7804      within an hour             94%  2019-05-05         NaN            0
#
#       minimum_nights  maximum_nights
# 0                  2             365
# 1                  2            1125
# 2                 30             180
# 3                  2             365
# 4                  5              24
# ...              ...             ...
# 7800               1             365
# 7801               1             365
# 7802               5            1125
# 7803               1             365
# 7804               2            1125
#
# [7805 rows x 17 columns]

# %% [markdown]
# Q7. **Drop the columns `minimum_nights` and `maximum_nights` without disturbing the original structure of the DataFrame.**

# %%
prop_df_copy = prop_df.copy()
prop_df_copy.drop(columns=['minimum_nights', 'maximum_nights'], inplace=True)

# %% [markdown]
# Q8. **Rename the index to `property_id`.**

# %% [markdown]
# Q9. **Convert the `acceptance_rate` column from object to float by removing the `%` symbol.**

# %%
prop_df['acceptance_rate'].apply(lambda x: type(x))
# Out:
# 0         <class 'str'>
# 1       <class 'float'>
# 2       <class 'float'>
# 3         <class 'str'>
# 4         <class 'str'>
#              ...
# 7800      <class 'str'>
# 7801    <class 'float'>
# 7802      <class 'str'>
# 7803      <class 'str'>
# 7804      <class 'str'>
# Name: acceptance_rate, Length: 7805, dtype: object

# %% [markdown]
# Q10. **Get the unique values for each of the `object` columns, displaying the output as a `Series`.**

# %%
def conv_acc_rate(x):
    if pd.isnull(x):
        return np.nan
    else:
        return int(x[:-1]) / 100

# %%
obj_cols = prop_df.columns[prop_df.dtypes == 'object']

prop_df[obj_cols].nunique()
# Out:
# neighborhood         39
# room_type             4
# response_time         4
# acceptance_rate      91
# host_since         2437
# last_review        1255
# dtype: int64

# %%
for col in obj_cols:
    print(pd.Series(prop_df[col].unique()))
    print('')
# Out:
# 0            Historic Anacostia
# 1                      Edgewood
# 2              Eastland Gardens
# 3              Kalorama Heights
# 4                 Spring Valley
# 5                 Dupont Circle
# 6             Cathedral Heights
# 7              Columbia Heights
# 8                          Shaw
# 9                 Union Station
# 10              Brightwood Park
# 11    Southwest Employment Area
# 12                     Ivy City
# 13            Howard University
# 14                       Takoma
# 15                 Capitol Hill
# 16                     Downtown
# 17             Congress Heights
# 18             Colonial Village
# 19                     Sheridan
# 20                 Lamont Riggs
# 21                   Georgetown
# 22                 Capitol View
# 23               Cleveland Park
# 24                      Douglas
# 25           Friendship Heights
# 26                     West End
# 27                    Brookland
# 28                    Hawthorne
# 29          North Michigan Park
# 30                      Mayfair
# 31              Fairfax Village
# 32                     Deanwood
# 33                    Woodridge
# 34         North Cleveland Park
# 35                River Terrace
# 36                      Twining
# 37               Near Southeast
# 38        Woodland/Fort Stanton
# dtype: object
#
# 0       Private room
# 1    Entire home/apt
# 2        Shared room
# 3         Hotel room
# dtype: object
#
# 0    a few days or more
# 1                   NaN
# 2    within a few hours
# 3        within an hour
# 4          within a day
# dtype: object
#
# 0     67%
# 1     NaN
# 2     85%
# 3     11%
# 4     96%
#      ...
# 87    47%
# 88    66%
# 89    19%
# 90    31%
# 91    42%
# Length: 92, dtype: object
#
# 0       2008-11-26
# 1       2008-12-12
# 2       2008-12-30
# 3       2009-01-26
# 4       2009-01-13
#            ...
# 2433    2020-05-03
# 2434    2020-11-27
# 2435    2019-09-22
# 2436    2021-09-13
# 2437    2020-03-05
# Length: 2438, dtype: object
#
# 0       2021-08-09
# 1       2021-09-11
# 2       2019-07-05
# 3       2016-09-22
# 4       2020-03-05
#            ...
# 1251    2021-03-26
# 1252    2021-01-25
# 1253    2021-05-03
# 1254    2021-04-29
# 1255    2021-03-03
# Length: 1256, dtype: object

# %% [markdown]
# Q11. **Get the `top-10` and the `bottom-10 neighborhoods` for a `Private room` along with the `number of appearances` in the DataFrame.**

# %%
prop_df_pvt_room = prop_df[prop_df['room_type'] == 'Private room']
prop_df_pvt_room
# Out:
#             id        neighborhood     room_type  accommodates  bedrooms  \
# 0         3686  Historic Anacostia  Private room             1       1.0
# 1         3943            Edgewood  Private room             2       1.0
# 2         4529    Eastland Gardens  Private room             4       1.0
# 3         4967            Edgewood  Private room             1       1.0
# 6         9097    Kalorama Heights  Private room             1       1.0
# ...        ...                 ...           ...           ...       ...
# 7789  52240462       Dupont Circle  Private room             2       NaN
# 7791  52240980       Dupont Circle  Private room             2       NaN
# 7792  52242602       Dupont Circle  Private room             2       NaN
# 7798  52259402   Cathedral Heights  Private room             4       1.0
# 7802  52269279     Brightwood Park  Private room             2       1.0
#
#       price  security_deposit  cleaning_fee  rating  superhost  \
# 0        55                25            25    4.60          0
# 1        71                50             0    4.81          0
# 2        54                25            50    4.66          0
# 3        99                50             0    4.74          1
# 6        42                50            25    4.86          0
# ...     ...               ...           ...     ...        ...
# 7789    158               100             0     NaN          0
# 7791    173                50           100     NaN          0
# 7792    166                 0           100     NaN          0
# 7798     54                 0            50     NaN          0
# 7802     40                50            50     NaN          0
#
#            response_time acceptance_rate  host_since last_review  num_reviews  \
# 0     a few days or more             67%  2008-11-26  2021-08-09           76
# 1                    NaN             NaN  2008-12-12  2021-09-11          434
# 2     within a few hours             NaN  2008-12-30  2019-07-05          102
# 3         within an hour             85%  2009-01-26  2016-09-22           31
# 6     within a few hours             11%  2009-01-13  2019-10-30          112
# ...                  ...             ...         ...         ...          ...
# 7789      within an hour             97%  2018-10-08         NaN            0
# 7791      within an hour             97%  2018-10-08         NaN            0
# 7792      within an hour             97%  2018-10-08         NaN            0
# 7798  within a few hours             57%  2020-03-05         NaN            0
# 7802      within an hour             94%  2015-06-15         NaN            0
#
#        latitude  longitude  minimum_nights  maximum_nights
# 0     38.863390 -76.988890               2             365
# 1     38.911950 -77.004560               2            1125
# 2     38.905850 -76.944690              30             180
# 3     38.914090 -76.993680               2             365
# 6     38.919660 -77.043060               2               7
# ...         ...        ...             ...             ...
# 7789  38.904300 -77.041650               2             365
# 7791  38.903540 -77.041500               2             365
# 7792  38.902940 -77.042280               2             365
# 7798  38.930070 -77.074490               1               7
# 7802  38.939073 -77.028088               5            1125
#
# [1876 rows x 19 columns]

# %% [markdown]
# Q12. **What is the `minimum`, `average`, `median` and `maximum number of persons` that an `Entire home/apt` accommodates?**

# %%
prop_df.loc[prop_df['room_type'] == 'Entire home/apt', 'accommodates'].mean()
# Out:
# 4.104604691572546

# %%
prop_df.loc[prop_df['room_type'] == 'Entire home/apt', 'accommodates'].median()
# Out:
# 4.0

# %%
prop_df.loc[prop_df['room_type'] == 'Entire home/apt', 'accommodates'].min()
# Out:
# 1

# %% [markdown]
# Q13. **How many people can be `frequently accommodated` in a Hotel room?**

# %%
prop_df.loc[prop_df['room_type'] == 'Hotel room', 'accommodates'].mode()
# Out:
# 0    6
# Name: accommodates, dtype: int64

# %% [markdown]
# Q14. **What is the `average price` of an `Entire Home/apt` within `Capitol Hill`?**

# %% [markdown]
# Q15. **What is the `minimum price` of a `Shared room` that accommodates less than `5 people`?**

# %% [markdown]
# Q16. **What is the `average rating` for a property that has an `acceptance rate` of less than 50%?**

# %% [markdown]
# Q17. **What is the `minimum acceptance rate` for a property that is hosted by a `superhost`?**

# %% [markdown]
# Q18. **What `percentage of properties` are owned by a `superhost` whose response time is `within an hour`?**

# %% [markdown]
# Q19. **What is the `average rating` of the properties owned by hosts who take a `few days or more` to respond?**

# %% [markdown]
# Q20. **What is the `minimum rating` of a property that is `owned by a superhost`?**

# %% [markdown]
# Q21. **What is the `average acceptance rate` for a property whose host doesn't take `more than few days` to respond?**

# %% [markdown]
# Q22. **Rank the `Entire Home/apt` properties situated near `Howard University` based on the `total_cost`.**

# %% [markdown]
# Q23. **What percentage of superhosts don't charge any `cleaning_fee`?**

# %% [markdown]
# Q24. **What is the `minimum response time` for a property which has a `rating of less than 3` and the `acceptance rating` being `less than 50%`?**

# %% [markdown]
# Q25. **Get the `average number of reviews` for each `room_type`, `superhost` and `response_time`.**

# %%
prop_df.groupby(['room_type','superhost'])[['response_time']].mean()
# Out:
# C:\Users\anves\AppData\Local\Temp\ipykernel_13644\4156779405.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   prop_df.groupby(['room_type','superhost'])[['response_time']].mean()
# Empty DataFrame
# Columns: []
# Index: [(Entire home/apt, 0), (Entire home/apt, 1), (Hotel room, 0), (Hotel room, 1), (Private room, 0), (Private room, 1), (Shared room, 0), (Shared room, 1)]

# %% [markdown]
# Q26. **Get the `count` of `ratings` grouped by `bedrooms` and `accomodates`.**

# %%
prop_df.groupby(['bedrooms','accommodates'])[['rating']].count().reset_index()
# Out:
#     bedrooms  accommodates  rating
# 0        1.0             1     414
# 1        1.0             2    1617
# 2        1.0             3     528
# 3        1.0             4     818
# 4        1.0             5      62
# ..       ...           ...     ...
# 67       7.0             7       0
# 68       7.0            12       1
# 69       7.0            16       2
# 70       8.0            16       1
# 71       9.0            16       2
#
# [72 rows x 3 columns]

# %% [markdown]
# Q27. **Get the `average` number of people that can be `accomodated` for each `room type` and the `security deposit`.**

# %%
prop_df.groupby(['room_type','security_deposit'])[['accommodates']].mean().reset_index
# Out:
# <bound method DataFrame.reset_index of                                   accommodates
# room_type       security_deposit
# Entire home/apt 0                     3.981081
#                 25                    2.981061
#                 50                    3.934807
#                 100                   4.547807
#                 250                   6.163636
#                 400                   6.589286
# Hotel room      0                     6.333333
#                 25                    5.428571
#                 50                    4.818182
# Private room    0                     2.123577
#                 25                    1.849776
#                 50                    2.054575
#                 100                   2.760479
#                 250                   3.230769
#                 400                   3.166667
# Shared room     0                     2.338462
#                 25                    2.358974
#                 50                    1.275000
#                 100                   2.833333>

# %% [markdown]
# Q28. **Get the `minimum price` for each category of `bedrooms`, `accomodates` and `cleaning fee`.**

# %%
prop_df.groupby(['bedrooms','accommodates','cleaning_fee'])['price'].min().reset_index()
# Out:
#      bedrooms  accommodates  cleaning_fee  price
# 0         1.0             1             0     10
# 1         1.0             1            25     23
# 2         1.0             1            50     20
# 3         1.0             1           100    100
# 4         1.0             1           150    999
# ..        ...           ...           ...    ...
# 201       7.0            16             0   1799
# 202       7.0            16           150   1514
# 203       8.0            16           100   1003
# 204       9.0            16             0    348
# 205       9.0            16           100    980
#
# [206 rows x 4 columns]

# %% [markdown]
# Q29. **Get the `average minimum nights` for each `response time`, `room_type` and `superhost`.**

# %%
prop_df.groupby(['response_time','room_type','superhost'])[['minimum_nights']].mean().reset_index()
# Out:
#          response_time        room_type  superhost  minimum_nights
# 0   a few days or more  Entire home/apt          0        9.279661
# 1   a few days or more  Entire home/apt          1        2.000000
# 2   a few days or more     Private room          0       14.924242
# 3   a few days or more      Shared room          0       45.473684
# 4         within a day  Entire home/apt          0       17.981538
# 5         within a day  Entire home/apt          1        5.041096
# 6         within a day     Private room          0       15.762712
# 7         within a day     Private room          1        8.052632
# 8         within a day      Shared room          0        2.000000
# 9   within a few hours  Entire home/apt          0        9.300341
# 10  within a few hours  Entire home/apt          1        6.723926
# 11  within a few hours     Private room          0        6.387931
# 12  within a few hours     Private room          1        8.021277
# 13  within a few hours      Shared room          0        5.000000
# 14      within an hour  Entire home/apt          0       18.762457
# 15      within an hour  Entire home/apt          1        4.967619
# 16      within an hour       Hotel room          0        1.000000
# 17      within an hour       Hotel room          1       15.200000
# 18      within an hour     Private room          0       11.871308
# 19      within an hour     Private room          1        4.720183
# 20      within an hour      Shared room          0        2.271429
# 21      within an hour      Shared room          1        1.375000

# %% [markdown]
# Q30. **Get the `count` of `response_time` for each `neighborhood` and by `superhost`.**

# %%
prop_df.groupby(['neighborhood', 'superhost'])[['response_time']].count().reset_index()
# Out:
#              neighborhood  superhost  response_time
# 0         Brightwood Park          0            187
# 1         Brightwood Park          1             64
# 2               Brookland          0             47
# 3               Brookland          1             27
# 4            Capitol Hill          0            318
# ..                    ...        ...            ...
# 73               West End          1             15
# 74  Woodland/Fort Stanton          0              5
# 75  Woodland/Fort Stanton          1              0
# 76              Woodridge          0             21
# 77              Woodridge          1             13
#
# [78 rows x 3 columns]

# %% [markdown]
# Q31. **Create a column `'avg_reviews_by_room_superhost'` to get the `average number of reviews` for each `room_type` and `superhost`.**

# %%
prop_df['avg_reviews_by_room_superhost'] = prop_df.groupby(['room_type','superhost'])[['num_reviews']].transform('mean')

# %%
prop_df
# Out:
#             id        neighborhood        room_type  accommodates  bedrooms  \
# 0         3686  Historic Anacostia     Private room             1       1.0
# 1         3943            Edgewood     Private room             2       1.0
# 2         4529    Eastland Gardens     Private room             4       1.0
# 3         4967            Edgewood     Private room             1       1.0
# 4         5589    Kalorama Heights  Entire home/apt             3       1.0
# ...        ...                 ...              ...           ...       ...
# 7800  52261187            Downtown  Entire home/apt             2       1.0
# 7801  52263116      Near Southeast  Entire home/apt             2       1.0
# 7802  52269279     Brightwood Park     Private room             2       1.0
# 7803  52271085            West End  Entire home/apt             2       1.0
# 7804  52281658            Edgewood  Entire home/apt             7       2.0
#
#       price  security_deposit  cleaning_fee  rating  superhost  \
# 0        55                25            25    4.60          0
# 1        71                50             0    4.81          0
# 2        54                25            50    4.66          0
# 3        99                50             0    4.74          1
# 4        99                50             0    4.54          0
# ...     ...               ...           ...     ...        ...
# 7800    299                 0            50     NaN          0
# 7801    200                50             0     NaN          0
# 7802     40                50            50     NaN          0
# 7803    139                 0             0     NaN          0
# 7804    134                 0           100     NaN          0
#
#            response_time acceptance_rate  host_since last_review  num_reviews  \
# 0     a few days or more             67%  2008-11-26  2021-08-09           76
# 1                    NaN             NaN  2008-12-12  2021-09-11          434
# 2     within a few hours             NaN  2008-12-30  2019-07-05          102
# 3         within an hour             85%  2009-01-26  2016-09-22           31
# 4     within a few hours             11%  2009-01-13  2020-03-05           95
# ...                  ...             ...         ...         ...          ...
# 7800                 NaN            100%  2021-02-13         NaN            0
# 7801                 NaN             NaN  2016-12-05         NaN            0
# 7802      within an hour             94%  2015-06-15         NaN            0
# 7803                 NaN            100%  2020-12-24         NaN            0
# 7804      within an hour             94%  2019-05-05         NaN            0
#
#        latitude  longitude  minimum_nights  maximum_nights  \
# 0     38.863390 -76.988890               2             365
# 1     38.911950 -77.004560               2            1125
# 2     38.905850 -76.944690              30             180
# 3     38.914090 -76.993680               2             365
# 4     38.918870 -77.040080               5              24
# ...         ...        ...             ...             ...
# 7800  38.904860 -77.030900               1             365
# 7801  38.879241 -77.008231               1             365
# 7802  38.939073 -77.028088               5            1125
# 7803  38.900117 -77.047827               1             365
# 7804  38.912933 -77.013079               2            1125
#
#       avg_reviews_by_room_superhost
# 0                         24.740716
# 1                         24.740716
# 2                         24.740716
# 3                         64.351899
# 4                         25.049204
# ...                             ...
# 7800                      25.049204
# 7801                      25.049204
# 7802                      24.740716
# 7803                      25.049204
# 7804                      25.049204
#
# [7805 rows x 20 columns]

# %% [markdown]
# Q32. **Create a column `'count_ratings_by_bedroom_accomodates'` to get the `count of ratings` grouped by `bedrooms` and `accomodates`.**

# %% [markdown]
# Q33. **Create a column `'avg_acc_room_sec_dep'` to get the `average` number of people that can be `accomodated` for each `room type` and the `security deposit`.**

# %%
prop_df['avg_acc_room_sec_dep'] = prop_df.groupby(['room_type','security_deposit'])[['accommodates']].transform('mean')

# %%
prop_df
# Out:
#             id        neighborhood        room_type  accommodates  bedrooms  \
# 0         3686  Historic Anacostia     Private room             1       1.0
# 1         3943            Edgewood     Private room             2       1.0
# 2         4529    Eastland Gardens     Private room             4       1.0
# 3         4967            Edgewood     Private room             1       1.0
# 4         5589    Kalorama Heights  Entire home/apt             3       1.0
# ...        ...                 ...              ...           ...       ...
# 7800  52261187            Downtown  Entire home/apt             2       1.0
# 7801  52263116      Near Southeast  Entire home/apt             2       1.0
# 7802  52269279     Brightwood Park     Private room             2       1.0
# 7803  52271085            West End  Entire home/apt             2       1.0
# 7804  52281658            Edgewood  Entire home/apt             7       2.0
#
#       price  security_deposit  cleaning_fee  rating  superhost  ...  \
# 0        55                25            25    4.60          0  ...
# 1        71                50             0    4.81          0  ...
# 2        54                25            50    4.66          0  ...
# 3        99                50             0    4.74          1  ...
# 4        99                50             0    4.54          0  ...
# ...     ...               ...           ...     ...        ...  ...
# 7800    299                 0            50     NaN          0  ...
# 7801    200                50             0     NaN          0  ...
# 7802     40                50            50     NaN          0  ...
# 7803    139                 0             0     NaN          0  ...
# 7804    134                 0           100     NaN          0  ...
#
#      acceptance_rate  host_since last_review num_reviews   latitude  \
# 0                67%  2008-11-26  2021-08-09          76  38.863390
# 1                NaN  2008-12-12  2021-09-11         434  38.911950
# 2                NaN  2008-12-30  2019-07-05         102  38.905850
# 3                85%  2009-01-26  2016-09-22          31  38.914090
# 4                11%  2009-01-13  2020-03-05          95  38.918870
# ...              ...         ...         ...         ...        ...
# 7800            100%  2021-02-13         NaN           0  38.904860
# 7801             NaN  2016-12-05         NaN           0  38.879241
# 7802             94%  2015-06-15         NaN           0  38.939073
# 7803            100%  2020-12-24         NaN           0  38.900117
# 7804             94%  2019-05-05         NaN           0  38.912933
#
#       longitude  minimum_nights  maximum_nights  \
# 0    -76.988890               2             365
# 1    -77.004560               2            1125
# 2    -76.944690              30             180
# 3    -76.993680               2             365
# 4    -77.040080               5              24
# ...         ...             ...             ...
# 7800 -77.030900               1             365
# 7801 -77.008231               1             365
# 7802 -77.028088               5            1125
# 7803 -77.047827               1             365
# 7804 -77.013079               2            1125
#
#       avg_reviews_by_room_superhost  avg_acc_room_sec_dep
# 0                         24.740716              1.849776
# 1                         24.740716              2.054575
# 2                         24.740716              1.849776
# 3                         64.351899              2.054575
# 4                         25.049204              3.934807
# ...                             ...                   ...
# 7800                      25.049204              3.981081
# 7801                      25.049204              3.934807
# 7802                      24.740716              2.054575
# 7803                      25.049204              3.981081
# 7804                      25.049204              3.981081
#
# [7805 rows x 21 columns]

# %% [markdown]
# Q34. **Create a column `'min_price_bedroom_acc_cl_fee'` to get the `minimum price` for each category of `bedrooms`, `accomodates` and `cleaning fee`.**

# %%
prop_df['min_price_bedroom_acc_cl_fee'] = prop_df.groupby(['bedrooms','accommodates','cleaning_fee'])[['price']].transform('min')

# %%
prop_df
# Out:
#             id        neighborhood        room_type  accommodates  bedrooms  \
# 0         3686  Historic Anacostia     Private room             1       1.0
# 1         3943            Edgewood     Private room             2       1.0
# 2         4529    Eastland Gardens     Private room             4       1.0
# 3         4967            Edgewood     Private room             1       1.0
# 4         5589    Kalorama Heights  Entire home/apt             3       1.0
# ...        ...                 ...              ...           ...       ...
# 7800  52261187            Downtown  Entire home/apt             2       1.0
# 7801  52263116      Near Southeast  Entire home/apt             2       1.0
# 7802  52269279     Brightwood Park     Private room             2       1.0
# 7803  52271085            West End  Entire home/apt             2       1.0
# 7804  52281658            Edgewood  Entire home/apt             7       2.0
#
#       price  security_deposit  cleaning_fee  rating  superhost  ...  \
# 0        55                25            25    4.60          0  ...
# 1        71                50             0    4.81          0  ...
# 2        54                25            50    4.66          0  ...
# 3        99                50             0    4.74          1  ...
# 4        99                50             0    4.54          0  ...
# ...     ...               ...           ...     ...        ...  ...
# 7800    299                 0            50     NaN          0  ...
# 7801    200                50             0     NaN          0  ...
# 7802     40                50            50     NaN          0  ...
# 7803    139                 0             0     NaN          0  ...
# 7804    134                 0           100     NaN          0  ...
#
#       host_since last_review num_reviews   latitude  longitude  \
# 0     2008-11-26  2021-08-09          76  38.863390 -76.988890
# 1     2008-12-12  2021-09-11         434  38.911950 -77.004560
# 2     2008-12-30  2019-07-05         102  38.905850 -76.944690
# 3     2009-01-26  2016-09-22          31  38.914090 -76.993680
# 4     2009-01-13  2020-03-05          95  38.918870 -77.040080
# ...          ...         ...         ...        ...        ...
# 7800  2021-02-13         NaN           0  38.904860 -77.030900
# 7801  2016-12-05         NaN           0  38.879241 -77.008231
# 7802  2015-06-15         NaN           0  38.939073 -77.028088
# 7803  2020-12-24         NaN           0  38.900117 -77.047827
# 7804  2019-05-05         NaN           0  38.912933 -77.013079
#
#       minimum_nights  maximum_nights  avg_reviews_by_room_superhost  \
# 0                  2             365                      24.740716
# 1                  2            1125                      24.740716
# 2                 30             180                      24.740716
# 3                  2             365                      64.351899
# 4                  5              24                      25.049204
# ...              ...             ...                            ...
# 7800               1             365                      25.049204
# 7801               1             365                      25.049204
# 7802               5            1125                      24.740716
# 7803               1             365                      25.049204
# 7804               2            1125                      25.049204
#
#       avg_acc_room_sec_dep  min_price_bedroom_acc_cl_fee
# 0                 1.849776                            23
# 1                 2.054575                            20
# 2                 1.849776                            10
# 3                 2.054575                            10
# 4                 3.934807                            31
# ...                    ...                           ...
# 7800              3.981081                            25
# 7801              3.934807                            20
# 7802              2.054575                            25
# 7803              3.981081                            20
# 7804              3.981081                           100
#
# [7805 rows x 22 columns]

# %% [markdown]
# Q35. **Create a column `'avg_min_nights'` to get the `average minimum nights` for each `response time`, `room_type` and `superhost`.**

# %%
prop_df['avg_min_nights'] = prop_df.groupby(['response_time','room_type','superhost'])[['minimum_nights']].transform('mean')

# %%
prop_df
# Out:
#             id        neighborhood        room_type  accommodates  bedrooms  \
# 0         3686  Historic Anacostia     Private room             1       1.0
# 1         3943            Edgewood     Private room             2       1.0
# 2         4529    Eastland Gardens     Private room             4       1.0
# 3         4967            Edgewood     Private room             1       1.0
# 4         5589    Kalorama Heights  Entire home/apt             3       1.0
# ...        ...                 ...              ...           ...       ...
# 7800  52261187            Downtown  Entire home/apt             2       1.0
# 7801  52263116      Near Southeast  Entire home/apt             2       1.0
# 7802  52269279     Brightwood Park     Private room             2       1.0
# 7803  52271085            West End  Entire home/apt             2       1.0
# 7804  52281658            Edgewood  Entire home/apt             7       2.0
#
#       price  security_deposit  cleaning_fee  rating  superhost  ...  \
# 0        55                25            25    4.60          0  ...
# 1        71                50             0    4.81          0  ...
# 2        54                25            50    4.66          0  ...
# 3        99                50             0    4.74          1  ...
# 4        99                50             0    4.54          0  ...
# ...     ...               ...           ...     ...        ...  ...
# 7800    299                 0            50     NaN          0  ...
# 7801    200                50             0     NaN          0  ...
# 7802     40                50            50     NaN          0  ...
# 7803    139                 0             0     NaN          0  ...
# 7804    134                 0           100     NaN          0  ...
#
#      last_review num_reviews   latitude  longitude  minimum_nights  \
# 0     2021-08-09          76  38.863390 -76.988890               2
# 1     2021-09-11         434  38.911950 -77.004560               2
# 2     2019-07-05         102  38.905850 -76.944690              30
# 3     2016-09-22          31  38.914090 -76.993680               2
# 4     2020-03-05          95  38.918870 -77.040080               5
# ...          ...         ...        ...        ...             ...
# 7800         NaN           0  38.904860 -77.030900               1
# 7801         NaN           0  38.879241 -77.008231               1
# 7802         NaN           0  38.939073 -77.028088               5
# 7803         NaN           0  38.900117 -77.047827               1
# 7804         NaN           0  38.912933 -77.013079               2
#
#       maximum_nights  avg_reviews_by_room_superhost  avg_acc_room_sec_dep  \
# 0                365                      24.740716              1.849776
# 1               1125                      24.740716              2.054575
# 2                180                      24.740716              1.849776
# 3                365                      64.351899              2.054575
# 4                 24                      25.049204              3.934807
# ...              ...                            ...                   ...
# 7800             365                      25.049204              3.981081
# 7801             365                      25.049204              3.934807
# 7802            1125                      24.740716              2.054575
# 7803             365                      25.049204              3.981081
# 7804            1125                      25.049204              3.981081
#
#       min_price_bedroom_acc_cl_fee  avg_min_nights
# 0                               23       14.924242
# 1                               20        1.375000
# 2                               10        6.387931
# 3                               10        4.720183
# 4                               31        9.300341
# ...                            ...             ...
# 7800                            25        1.375000
# 7801                            20        1.375000
# 7802                            25       11.871308
# 7803                            20        1.375000
# 7804                           100       18.762457
#
# [7805 rows x 23 columns]

# %% [markdown]
# Q36. **Create a column `'count_resp_time'` to get the `count of response_time` for each `neighborhood` and by `superhost`.**

# %%
prop_df['count_resp_time'] =prop_df.groupby(['neighborhood','superhost'])[['response_time']].transform('count')

# %%
prop_df
# Out:
#             id        neighborhood        room_type  accommodates  bedrooms  \
# 0         3686  Historic Anacostia     Private room             1       1.0
# 1         3943            Edgewood     Private room             2       1.0
# 2         4529    Eastland Gardens     Private room             4       1.0
# 3         4967            Edgewood     Private room             1       1.0
# 4         5589    Kalorama Heights  Entire home/apt             3       1.0
# ...        ...                 ...              ...           ...       ...
# 7800  52261187            Downtown  Entire home/apt             2       1.0
# 7801  52263116      Near Southeast  Entire home/apt             2       1.0
# 7802  52269279     Brightwood Park     Private room             2       1.0
# 7803  52271085            West End  Entire home/apt             2       1.0
# 7804  52281658            Edgewood  Entire home/apt             7       2.0
#
#       price  security_deposit  cleaning_fee  rating  superhost  ...  \
# 0        55                25            25    4.60          0  ...
# 1        71                50             0    4.81          0  ...
# 2        54                25            50    4.66          0  ...
# 3        99                50             0    4.74          1  ...
# 4        99                50             0    4.54          0  ...
# ...     ...               ...           ...     ...        ...  ...
# 7800    299                 0            50     NaN          0  ...
# 7801    200                50             0     NaN          0  ...
# 7802     40                50            50     NaN          0  ...
# 7803    139                 0             0     NaN          0  ...
# 7804    134                 0           100     NaN          0  ...
#
#      num_reviews   latitude  longitude minimum_nights  maximum_nights  \
# 0             76  38.863390 -76.988890              2             365
# 1            434  38.911950 -77.004560              2            1125
# 2            102  38.905850 -76.944690             30             180
# 3             31  38.914090 -76.993680              2             365
# 4             95  38.918870 -77.040080              5              24
# ...          ...        ...        ...            ...             ...
# 7800           0  38.904860 -77.030900              1             365
# 7801           0  38.879241 -77.008231              1             365
# 7802           0  38.939073 -77.028088              5            1125
# 7803           0  38.900117 -77.047827              1             365
# 7804           0  38.912933 -77.013079              2            1125
#
#       avg_reviews_by_room_superhost  avg_acc_room_sec_dep  \
# 0                         24.740716              1.849776
# 1                         24.740716              2.054575
# 2                         24.740716              1.849776
# 3                         64.351899              2.054575
# 4                         25.049204              3.934807
# ...                             ...                   ...
# 7800                      25.049204              3.981081
# 7801                      25.049204              3.934807
# 7802                      24.740716              2.054575
# 7803                      25.049204              3.981081
# 7804                      25.049204              3.981081
#
#       min_price_bedroom_acc_cl_fee  avg_min_nights  count_resp_time
# 0                               23       14.924242               37
# 1                               20        1.375000              174
# 2                               10        6.387931               13
# 3                               10        4.720183              140
# 4                               31        9.300341              141
# ...                            ...             ...              ...
# 7800                            25        1.375000              192
# 7801                            20        1.375000               38
# 7802                            25       11.871308              187
# 7803                            20        1.375000              175
# 7804                           100       18.762457              174
#
# [7805 rows x 24 columns]

# %% [markdown]
# Q37. **Get the `average number of reviews` for each `room_type` and `superhost` along with `response time` in the columns.**

# %%
prop_df['avg_reviews_by_room_superhost'] = prop_df.groupby(['room_type','superhost'])[['num_reviews']].transform('mean')

# %%
prop_df
# Out:
#             id        neighborhood        room_type  accommodates  bedrooms  \
# 0         3686  Historic Anacostia     Private room             1       1.0
# 1         3943            Edgewood     Private room             2       1.0
# 2         4529    Eastland Gardens     Private room             4       1.0
# 3         4967            Edgewood     Private room             1       1.0
# 4         5589    Kalorama Heights  Entire home/apt             3       1.0
# ...        ...                 ...              ...           ...       ...
# 7800  52261187            Downtown  Entire home/apt             2       1.0
# 7801  52263116      Near Southeast  Entire home/apt             2       1.0
# 7802  52269279     Brightwood Park     Private room             2       1.0
# 7803  52271085            West End  Entire home/apt             2       1.0
# 7804  52281658            Edgewood  Entire home/apt             7       2.0
#
#       price  security_deposit  cleaning_fee  rating  superhost  ...  \
# 0        55                25            25    4.60          0  ...
# 1        71                50             0    4.81          0  ...
# 2        54                25            50    4.66          0  ...
# 3        99                50             0    4.74          1  ...
# 4        99                50             0    4.54          0  ...
# ...     ...               ...           ...     ...        ...  ...
# 7800    299                 0            50     NaN          0  ...
# 7801    200                50             0     NaN          0  ...
# 7802     40                50            50     NaN          0  ...
# 7803    139                 0             0     NaN          0  ...
# 7804    134                 0           100     NaN          0  ...
#
#      num_reviews   latitude  longitude minimum_nights  maximum_nights  \
# 0             76  38.863390 -76.988890              2             365
# 1            434  38.911950 -77.004560              2            1125
# 2            102  38.905850 -76.944690             30             180
# 3             31  38.914090 -76.993680              2             365
# 4             95  38.918870 -77.040080              5              24
# ...          ...        ...        ...            ...             ...
# 7800           0  38.904860 -77.030900              1             365
# 7801           0  38.879241 -77.008231              1             365
# 7802           0  38.939073 -77.028088              5            1125
# 7803           0  38.900117 -77.047827              1             365
# 7804           0  38.912933 -77.013079              2            1125
#
#       avg_reviews_by_room_superhost  avg_acc_room_sec_dep  \
# 0                         24.740716              1.849776
# 1                         24.740716              2.054575
# 2                         24.740716              1.849776
# 3                         64.351899              2.054575
# 4                         25.049204              3.934807
# ...                             ...                   ...
# 7800                      25.049204              3.981081
# 7801                      25.049204              3.934807
# 7802                      24.740716              2.054575
# 7803                      25.049204              3.981081
# 7804                      25.049204              3.981081
#
#       min_price_bedroom_acc_cl_fee  avg_min_nights  count_resp_time
# 0                               23       14.924242               37
# 1                               20        1.375000              174
# 2                               10        6.387931               13
# 3                               10        4.720183              140
# 4                               31        9.300341              141
# ...                            ...             ...              ...
# 7800                            25        1.375000              192
# 7801                            20        1.375000               38
# 7802                            25       11.871308              187
# 7803                            20        1.375000              175
# 7804                           100       18.762457              174
#
# [7805 rows x 24 columns]

# %% [markdown]
# Q38. **Get the `count of ratings` grouped by `bedrooms` and `accomodates` in the columns.**

# %%
prop_df.groupby(['bedrooms','accommodates'])[['rating']].count().reset_index()
# Out:
#     bedrooms  accommodates  rating
# 0        1.0             1     414
# 1        1.0             2    1617
# 2        1.0             3     528
# 3        1.0             4     818
# 4        1.0             5      62
# ..       ...           ...     ...
# 67       7.0             7       0
# 68       7.0            12       1
# 69       7.0            16       2
# 70       8.0            16       1
# 71       9.0            16       2
#
# [72 rows x 3 columns]

# %% [markdown]
# Q39. **What is the `average` number of people that can be `accomodated` for each `room type` and the `security deposit` in the `columns`.**

# %% [markdown]
# Q40. **What is the `minimum price` for each category of `bedrooms` and by the `accomodates` and `cleaning fee` in the `columns`.**

# %% [markdown]
# Q41. **What is the `average minimum nights` for each `response time` and for each `room_type` and `superhost` in the `columns`.**

# %% [markdown]
# Q42. **Get the count of `response_time` for each `neighborhood` and by `superhost` in the `columns`.**

# %% [markdown]
# Q43. **`Melt` the `result` of `Q37` to a normal DataFrame.**

# %% [markdown]
# Q44. **`Melt` the `result` of `Q38` to a normal DataFrame.**

# %% [markdown]
# Q45. **`Melt` the `result` of `Q39` to a normal DataFrame.**

# %% [markdown]
# Q46. **`Melt` the `result` of `Q40` to a normal DataFrame.**

# %% [markdown]
# Q47. **`Melt` the `result` of `Q41` to a normal DataFrame.**

# %% [markdown]
# Q48. **`Melt` the `result` of `Q42` to a normal DataFrame.**

# %% [markdown]
# Q49. **`Pivot` the `result` of `Q25` to match the `results` of `Q37`.**

# %% [markdown]
# Q50. **`Pivot` the `result` of `Q26` to match the `results` of `Q38`.**

# %% [markdown]
# Q51. **`Pivot` the `result` of `Q27` to match the `results` of `Q39`.**

# %% [markdown]
# Q52. **`Pivot` the `result` of `Q28` to match the `results` of `Q40`.**

# %% [markdown]
# Q53. **`Pivot` the `result` of `Q29` to match the `results` of `Q41`.**

# %% [markdown]
# Q54. **`Pivot` the `result` of `Q30` to match the `results` of `Q42`.**

# %% [markdown]
# ***The End***
